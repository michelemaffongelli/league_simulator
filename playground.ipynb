# %%
from leaguefinalversion import Teams, League, Matches, Stats, Run

# %%
from fifa import *

# %%
simulatore = Run(31, 23, 38)
# Out:
# c:\Users\Michele Maffongelli\Desktop\MASTER\PROGRAMMING WITH PYTHON\Assignment\fifa.py:9: DtypeWarning: Columns (32,38,39,40,41,49,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   F = pd.read_csv("male_teams.csv")
#      league_id      team_name  ...  club_worth_eur_normalized  overall_normalized
# 9           31          Inter  ...                   0.128304            0.054426
# 16          31       Juventus  ...                   0.290338            0.053770
# 22          31          Milan  ...                   0.148719            0.053115
# 27          31         Napoli  ...                   0.079768            0.052459
# 28          31           Roma  ...                   0.081390            0.052459
# 35          31       Atalanta  ...                   0.047320            0.051803
# 36          31          Lazio  ...                   0.044345            0.051803
# ...
